# %% [markdown]
# # Library Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # SP500_Prices.csv

# %%
path = '../processeddata/SP500_Prices.csv'
df = pd.read_csv(path)

df.set_index(['Date'],inplace=True)

display(df)
print(df.describe())

print("\n Mean:")
print(df.mean())
 
print("\n Median:")
print(df.median())
 
print("\n Mode:")
print(df.mode())
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-02-08  1509.390015  1518.310059  1509.390015  1517.930054  1517.930054
# 2013-02-11  1517.930054  1518.310059  1513.609985  1517.010010  1517.010010
# 2013-02-12  1517.010010  1522.290039  1515.609985  1519.430054  1519.430054
# 2013-02-13  1519.430054  1524.689941  1515.930054  1520.329956  1520.329956
# 2013-02-14  1520.329956  1523.140015  1514.020020  1521.380005  1521.380005
# ...                 ...          ...          ...          ...          ...
# 2018-01-31  2832.409912  2839.260010  2813.040039  2823.810059  2823.810059
# 2018-02-01  2816.449951  2835.959961  2812.699951  2821.979980  2821.979980
# 2018-02-02  2808.919922  2808.919922  2759.969971  2762.129883  2762.129883
# 2018-02-05  2741.060059  2763.389893  2638.169922  2648.939941  2648.939941
# 2018-02-06  2614.780029  2701.040039  2593.070068  2695.139893  2695.139893
#
#                 Volume
# Date
# ...

# %%
print("\nClose:")
print(df['Close'].plot())
# Out:
# Close:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print("\nOpen:")
print(df['Open'].plot())
# Out:
# Open:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print("\nHigh:")
print(df['High'].plot())
# Out:
# High:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print("\nLow:")
print(df['Low'].plot())
# Out:
# Low:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print("\nVolume:")
print(df['Volume'].plot())
# Out:
# Volume:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # SP500_Individual.csv

# %%
#Data Frame Descibe
path = '../rawdata/SP500_individual.csv'
df = pd.read_csv(path)

display(df)
print("Description:")
print(df.describe())
# Out:
#     Symbol                    Name                  Sector
# 0      MMM              3M Company             Industrials
# 1      AOS         A.O. Smith Corp             Industrials
# 2      ABT     Abbott Laboratories             Health Care
# 3     ABBV             AbbVie Inc.             Health Care
# 4      ACN           Accenture plc  Information Technology
# ..     ...                     ...                     ...
# 500    XYL              Xylem Inc.             Industrials
# 501    YUM         Yum! Brands Inc  Consumer Discretionary
# 502    ZBH  Zimmer Biomet Holdings             Health Care
# 503   ZION           Zions Bancorp              Financials
# 504    ZTS                  Zoetis             Health Care
#
# [505 rows x 3 columns]
# Description:
#        Symbol        Name                  Sector
# count     505         505                     505
# unique    505         505                      11
# top       STX  3M Company  Consumer Discretionary
# ...

# %%
# Plot number of companies in a sector
fig, ax = plt.subplots()
df['Sector'].value_counts().plot(ax=ax, kind='bar')

# %% [markdown]
# # all_stocks_5yr.csv

# %%
#Data Frame Descibe
path = '../processeddata/all_stocks_5yr.csv'
df = pd.read_csv(path)

print(display(df))
print("Description:")
print(df.describe())
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]
# None
# Description:
#                 open           high            low          close  \
# count  619029.000000  619032.000000  619032.000000  619040.000000
# ...

# %%
# We are only selecting a company from each sector

# Amazon (Consumer Discretionary), Apple (IT),  JPMorgan Chase & Co. (Financial), PACCAR Inc. (Industrial), 
# Aetna Inc (Health Care), Costco Wholesale Corp. (Consumer Staples), Simon Property Group (Real Estate), Exxon Mobil Corp. (Energy)
# PG&E Corp. (Utilities), Air Products & Chemicals Inc (Materials), AT&T Inc. (Telecommunication Services) 
path = '../processeddata/individual_stocks_5yr/individual_stocks_5yr/'

comp = ['AMZN', 'AAPL', 'JPM', 'PCAR', 'AET', 'COST', 'SPG', 'XOM', 'PCG', 'APD', 'T']

for c in comp:
    p = path + c + '_data.csv' 
    df = pd.read_csv(p)
    df.set_index(['date'],inplace=True)

    lines = df['close'].plot.line()

# %%
# Comparing Amazon to Nordstrom
compare = ['JWN', 'AMZN']

for c in compare:
    p = path + c + '_data.csv' 
    df = pd.read_csv(p)
    df.set_index(['date'],inplace=True)

    df['close'].plot.line()
